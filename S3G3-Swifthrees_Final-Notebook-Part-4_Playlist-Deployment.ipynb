# %% [markdown]
# ## Deploy Playlist to Spotify
#
# This notebook shows how to deploy the recommender engine generated tracks as a playlist in Spotify using `spotipy` module.

# %%
# !pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.23.0-py3-none-any.whl (29 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Downloading redis-5.0.1-py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.3/250.3 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (2.31.0)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (2.0.7)
# Requirement already satisfied: async-timeout>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from redis>=3.5.3->spotipy) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (2023.7.22)
# Installing collected packages: redis, spotipy
# Successfully installed redis-5.0.1 spotipy-2.23.0

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials, SpotifyOAuth

import getpass
import time

# %% [markdown]
# ## Setup credentials

# %%
client_id = getpass.getpass(prompt='Enter Spotify app client id: ')
# Out:
# Enter Spotify app client id: ··········

# %%
client_secret = getpass.getpass(prompt='Enter Spotify app client secret: ')
# Out:
# Enter Spotify app client secret: ··········

# %% [markdown]
# HOWTO find your Spotify username:
# 1.  Head to open.spotify.com and log in with your account details
# 2.  Click the 👤 icon -> Account
# 3. A new tab should open. Under Account, click Edit Profile
# 4. Username is the first field, on top of the email field.
#
# Copy your username and replace the string below

# %%
### MODIFY THIS...find your username here -> https://www.spotify.com/us/account/profile/
username = '7lrxfwfsjiswt3msn1b2ncjjq'
###
redirect_uri='https://localhost:8081/'
scope = "user-library-modify playlist-modify-public"

# %%
# Authenticate with Spotify
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=client_id,
                                               client_secret=client_secret,
                                               redirect_uri=redirect_uri,
                                               scope=scope, open_browser=False))

# %% [markdown]
# ## Add track ids from recommender engine
# Replace this with most recent track id recommendations

# %%
### MODIFY THIS
seed_track = 'mrld - Ligaya'
track_id_list = ['2BgD4nRyx9EZ5o8YEnjRSV', '3vGkyQlCw8LklNip0ZUELC',
       '4wnY5k0diSG5naOgbtCOqK', '24ngpWhBOxKJtIPnzSNX8c',
       '0wUSZjJVblGKntOqBSWMdo', '2WUhR1SraSy0SVIQKohJb6',
       '5jLEQLkEU8Sb2fG5UQcwDM', '6FFtbC1K2aNeCS376paoHN',
       '4aUf4lzQ1di5JajZ4a9FuI', '1qoXYfWILyuN0EatImGlma']
###

# %% [markdown]
# ## Deploy playlist to Spotify

# %% [markdown]
# ### 1. Create new playlist
# **IMPORTANT:** To run next cell:
# 1. Click the URL after "Go to the following URL". It should open a new tab
# 2. Go to that new tab. It should be a blank webpage.
# 3. Copy the URL and past it in the prompt box after "Enter the URL you were redirected to:"
#
# If successful, cell below would return the new playlist data in the usual JSON output format

# %%
# new_playlist_name = f"From Charts to Hearts: {seed_track}"
new_playlist_name = f"From Charts to Hearts: mrld"
new_playlist = sp.user_playlist_create(username, name=new_playlist_name)
new_playlist
# Out:
# {'collaborative': False,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/3xOS82fWlydkLnL8EkeI3Y'},
#  'followers': {'href': None, 'total': 0},
#  'href': 'https://api.spotify.com/v1/playlists/3xOS82fWlydkLnL8EkeI3Y',
#  'id': '3xOS82fWlydkLnL8EkeI3Y',
#  'images': [],
#  'name': 'From Charts to Hearts: mrld',
#  'owner': {'display_name': 'jd',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/7lrxfwfsjiswt3msn1b2ncjjq'},
#   'href': 'https://api.spotify.com/v1/users/7lrxfwfsjiswt3msn1b2ncjjq',
#   'id': '7lrxfwfsjiswt3msn1b2ncjjq',
#   'type': 'user',
#   'uri': 'spotify:user:7lrxfwfsjiswt3msn1b2ncjjq'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'MSxmMDBjMGRiOTI2ZjgwMDE2ZTdkNjczZTM2MmQyOTJlM2ViYmUyNmNh',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/3xOS82fWlydkLnL8EkeI3Y/tracks',
#   'items': [],
#   'limit': 100,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 0},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:3xOS82fWlydkLnL8EkeI3Y'}

# %%
new_playlist['id']
# Out:
# '3xOS82fWlydkLnL8EkeI3Y'

# %% [markdown]
# ### 2. Add tracks to the newly created playlist

# %%
playlist_id=new_playlist['id']
sp.user_playlist_add_tracks(username, playlist_id, track_id_list)
# Out:
# {'snapshot_id': 'Miw0MTUyNjRmZjVlNDI4Njg4YjYyNWE5ODQ5OThkOTA0NjQwNmM0YzNj'}
